# %%
from IPython import display
display.Image("./matrix1.png")

# %% [markdown]
# Note: the tranpose rules
#
# $$ (AB)^T = B^TA^T $$
#
# $$ a^Tb = b^Ta $$

# %%
from IPython import display
display.Image("./matrix2.png")

# %% [markdown]
# where b is scalar, B is constant matrix

# %% [markdown]
# derive vector derivative $\frac{d(x^Tx)}{dx} = 2x $
#
# $ \frac{d(x^Tx)}{dx} = [ \frac{d(c_1^2 + c_2^2 +... + c_l^2)}{dc_1} , \frac{d(c_1^2 + c_2^2 +... + c_l^2)}{dc_2},  \frac{d(c_1^2 + c_2^2 +... + c_l^2)}{dc_l} ]  = [2c_1, 2c_2, ... 2c_l ] = 2[c_1, c_2, c_l] = 2c  $
